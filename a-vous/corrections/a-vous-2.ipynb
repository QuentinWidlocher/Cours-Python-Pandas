# %% [markdown]
# # 📝 À vous (2)
#
# En vous servant du fichier `../demo-pandas/titanic.csv`, sortez les informations demandées.
#
#
# ## Exercices 1
#
# Dans ces exercices, ne sortez pas forcément les données dans des tableaux, vous pouvez utiliser `print()` pour afficher des chiffres.
# Pour chaque exercice, vérifiez que le total correspond bien au total de lignes du tableau (890) en additionnant vos résultat
#
# ### Exercice 1.1
#
# Affichez le nombre de passagers qui ont voyagés en première classe, deuxième classe et troisième classe (Et vérifiez que le total correspond bien au total de ligne du tableau (890))

# %%
import pandas as p
titanic = p.read_csv("../../demo-pandas/titanic.csv")

first_class = titanic[titanic["Pclass"] == 1].shape[0]
second_class = titanic[titanic["Pclass"] == 2].shape[0]
third_class = titanic[titanic["Pclass"] == 3].shape[0]

print(f"{first_class} passagers en première classe")
print(f"{second_class} passagers en deuxième classe")
print(f"{third_class} passagers en troisième classe")

first_class + second_class + third_class == 890
# Out:
# 216 passagers en première classe
# 184 passagers en deuxième classe
# 490 passagers en troisième classe
# True

# %% [markdown]
# ### Exercice 1.2
#
# Affichez le nombre et le pourcentage d'hommes et de femmes à avoir voyagé à bord. (Et vérifiez que le total correspond bien au total de ligne du tableau (890))

# %%
is_male = titanic["Sex"] == "male"
is_female = titanic["Sex"] == "female"

total = titanic.shape[0]
males = titanic[is_male].shape[0]
females = titanic[is_female].shape[0]

print(f"Pourcentage d'hommes à avoir voyagés à bord : {round(males/total, 2) * 100}% ({males})")
print(f"Pourcentage de femmes à avoir voyagées à bord : {round(females/total, 2) * 100}% ({females})")

males + females == total
# Out:
# Pourcentage d'hommes à avoir voyagés à bord : 65.0% (576)
# Pourcentage de femmes à avoir voyagées à bord : 35.0% (314)
# True

# %% [markdown]
# ### Exercice 1.3
#
# Affichez le pourcentage d'hommes et le pourcentage de femmes à avoir survécu et à ne pas avoir survécu. (Et vérifiez que le total correspond bien au total de ligne du tableau (890))

# %%
has_survived = titanic["Survived"] == 1
has_not_survived = titanic["Survived"] == 0

surviving_males = titanic[is_male & has_survived].shape[0]
not_surviving_males = titanic[is_male & has_not_survived].shape[0]

surviving_females = titanic[is_female & has_survived].shape[0]
not_surviving_females = titanic[is_female & has_not_survived].shape[0]

print(f"Pourcentage d'hommes à avoir survécu : {round(surviving_males/total, 2) * 100}% ({surviving_males})")
print(f"Pourcentage d'hommes à ne pas avoir survécu : {round(not_surviving_males/total, 2) * 100}% ({not_surviving_males})")
print(f"Pourcentage de femmes à avoir survécu : {round(surviving_females/total, 2) * 100}% ({surviving_females})")
print(f"Pourcentage de femmes à ne pas avoir survécu : {round(not_surviving_females/total, 2) * 100}% ({not_surviving_females})")

surviving_males + not_surviving_males + surviving_females + not_surviving_females == total
# Out:
# Pourcentage d'hommes à avoir survécu : 12.0% (109)
# Pourcentage d'hommes à ne pas avoir survécu : 52.0% (467)
# Pourcentage de femmes à avoir survécu : 26.0% (233)
# Pourcentage de femmes à ne pas avoir survécu : 9.0% (81)
# True

# %% [markdown]
# ## Exercices 2
#
# Dans ces exercices, sortez les résultat sous la forme de tableaux filtrés
#
# ### Exercice 2.1
#
# Affichez la liste des passagers de plus de 70 ans

# %%
titanic[titanic["Age"] > 70]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 630  male  80.0      0      0     27042  30.0000   A23        S

# %% [markdown]
# ## Exercice 2.2
#
# Affichez la liste des passager qui ont entre 30 et 60 ans

# %%
titanic[(titanic["Age"] > 30) & (titanic["Age"] < 60)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 872          874         0       3
# 878          880         1       1
# 880          882         0       3
# 884          886         0       3
# 889          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Exercice 2.3
#
# Par rapport à l'exercice d'avant, affichez tous les autres

# %%
titanic[(titanic["Age"] <= 30) | (titanic["Age"] >= 60)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 882          884         0       2
# 883          885         0       3
# 885          887         0       2
# 886          888         1       1
# 888          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Exercice 2.4
#
# Une comtesse a embarqué sur le titanic, vous devriez pouvoir la trouvez sans chercher son nom sur internet.

# %%
titanic[titanic["Name"].str.contains("Countess")]
# Out:
#      PassengerId  Survived  Pclass  \
# 759          760         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 759  Rothes, the Countess. of (Lucy Noel Martha Dye...  female  33.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 759      0  110152  86.5   B77        S

# %% [markdown]
# ### Exercice 2.5
#
# Affichez uniquement le nom des femmes de plus de 30 ans qui ont payé entre 80£ et 90£ pour leur ticket et ont embarqué à Southampton, sans leurs familles (époux et frères/soeurs)

# %%
is_female = (titanic["Sex"] == "female")
is_over_30 = (titanic["Age"] > 30)
paid_between_80_and_90 = (titanic["Fare"] > 80) & (titanic["Fare"] < 90)
from_southampton = (titanic["Embarked"] == "S")
embarked_alone = (titanic["Parch"] == 0) & (titanic["SibSp"] == 0)

titanic[is_female & is_over_30 & paid_between_80_and_90 & from_southampton & embarked_alone][["Name"]]
# Out:
#                                                   Name
# 759  Rothes, the Countess. of (Lucy Noel Martha Dye...
